# %% [markdown]
# # Foundamental Course — Week 1 Practice: Data profiling artifacts (CSV → JSON/Markdown)
#
# ---
#
# ## Pre-study (Self-learn)
#
# Foundamental Course assumes Self-learn is complete. If you need a refresher:
#
# - [Foundamental Course Pre-study index](../PRESTUDY.md)
# - [Self-learn — Conda environment management](../self_learn/Chapters/2/03_conda_environments.md)
# - [Self-learn — Modules and exception handling](../self_learn/Chapters/2/02_modules_exceptions.md)
#
# ---
#
# This is a guided practice notebook to reinforce Week 1's goals:
#
# - stable environments
# - deterministic data profiling outputs
#
# ## What success looks like
#
# - You can run the notebook end-to-end.
# - You create deterministic artifacts under `output/`:
#   - `output/profile.json`
#   - `output/profile.md`
# - You can swap in your own CSV and still get the same output structure.
#
# ## References (docs)
# - Python `venv` (official): https://docs.python.org/3/library/venv.html
# - pip user guide (official): https://pip.pypa.io/en/stable/user_guide/
# - Python errors/exceptions (official): https://docs.python.org/3/tutorial/errors.html
# - Python `logging` (official): https://docs.python.org/3/library/logging.html
# - Pandas getting started: https://pandas.pydata.org/docs/getting_started/index.html
# - Pandas I/O (CSV): https://pandas.pydata.org/docs/user_guide/io.html

# %% [markdown]
# ## Setup
#
# Run this in an environment that already has `pandas` installed.
#
# ### Checkpoint
#
# - If `import pandas as pd` fails, fix your environment first (Week 1 Part 01).

# %%
import logging
from pathlib import Path

import pandas as pd

# %%
logging.basicConfig(level=logging.INFO, format='%(levelname)s %(message)s')
logger = logging.getLogger('week1')

OUTPUT_DIR = Path('output')
OUTPUT_DIR.mkdir(exist_ok=True)
OUTPUT_DIR

# %% [markdown]
# ## Create or load a CSV
#
# Replace sample generation with `pd.read_csv(...)` for your real dataset.

# %%
df = pd.DataFrame({
    'user_id': [1, 2, 3, 4, 5],
    'age': [23, None, 31, 45, 29],
    'country': ['US', 'US', 'SG', None, 'CN'],
    'purchase_amount': [12.5, 0.0, 7.99, 103.2, None],
})
csv_path = OUTPUT_DIR / 'sample.csv'
df.to_csv(csv_path, index=False)
logger.info('Wrote sample CSV to: %s' % csv_path)
df

# %% [markdown]
# ## Basic profiling
#
# Starter checks you can reuse in `data_profile.py`.

# %%
df = pd.read_csv(csv_path)
logger.info('Read CSV: rows=%s cols=%s' % (len(df), len(df.columns)))

profile = {
    'n_rows': int(df.shape[0]),
    'n_cols': int(df.shape[1]),
    'dtypes': {k: str(v) for k, v in df.dtypes.items()},
    'missing_by_col': df.isna().sum().to_dict(),
    'duplicate_rows': int(df.duplicated().sum()),
}
profile

# %%
numeric_stats = df.select_dtypes(include='number').describe().to_dict()
numeric_stats

# %% [markdown]
# ## Export outputs (JSON + Markdown)
#
# Export artifacts to `output/` so runs are reproducible.

# %%
import json

out_json = OUTPUT_DIR / 'profile.json'
out_md = OUTPUT_DIR / 'profile.md'

with out_json.open('w', encoding='utf-8') as f:
    json.dump({'profile': profile, 'numeric_stats': numeric_stats}, f, ensure_ascii=False, indent=2)

md_lines = [
    '# Data Profile',
    '',
    'Rows: {}'.format(profile['n_rows']),
    'Cols: {}'.format(profile['n_cols']),
    '',
    '## Missing Values',
    '',
]
for k, v in profile['missing_by_col'].items():
    md_lines.append('- **{}**: {}'.format(k, v))

out_md.write_text('\n'.join(md_lines), encoding='utf-8')

logger.info('Wrote: %s' % out_json)
logger.info('Wrote: %s' % out_md)
str(out_json), str(out_md)

# %% [markdown]
# ## Exercise: required columns check
#
# Add a required-columns guard so your profiling script fails fast when the input schema is wrong.
#
# Goal:
#
# - If any required columns are missing, raise a clear error.
# - Otherwise do nothing.
#
# Keep this helper small and reusable (you will use this pattern a lot later).

# %%
from typing import List


def require_columns_todo(df: pd.DataFrame, required: List[str]) -> None:
    # TODO: implement.
    return None


print("Implement require_columns_todo().")

# %% [markdown]
# ## Appendix: Solutions (peek only after trying)
#
# Reference implementation for the required-columns helper.

# %%
from typing import List


def require_columns_todo(df: pd.DataFrame, required: List[str]) -> None:
    missing = [c for c in required if c not in df.columns]
    if missing:
        raise ValueError(f"Missing required columns: {missing}")


# Quick check (should pass)
require_columns_todo(df, ["user_id", "age"])
print("ok")
