# %% [markdown]
# # Level 2 - Week 7 - 01 Planning Patterns
#
# **Estimated time:** 60-90 minutes
#
# ## Learning Objectives
#
# - Define a fixed plan template
# - Compare fixed vs replanning
# - Set plan budgets

# %% [markdown]
# ## Overview
#
# Planning depth must be controlled.
# Use fixed plan or replanning based on task predictability.
#
# ## Practice Steps
#
# - Write a fixed plan template.
# - Add a replanning rule.

# %% [markdown]
# ### Sample code
#
# Fixed plan template and replanning hook.

# %%
FIXED_PLAN = [
    'identify needed info',
    'call tools',
    'synthesize answer',
    'self-check',
]

print(FIXED_PLAN)

# %% [markdown]
# ### Student fill-in
#
# Write a plan for a sample task.

# %%
# TODO: write a fixed plan for a sample question

# %% [markdown]
# ## Self-check
#
# - Do you cap plan length?
# - Is replanning triggered by empty hits?

# %% [markdown]
# Legacy practice content from practice.ipynb
#
# # Level 2 — Week 7 Practice: Agent Guardrails
#
# **Estimated time:** 60–90 minutes
#
# ## Learning Objectives
#
# - Define guardrails for tools and steps
# - Enforce budgets and timeouts
# - Produce structured error reports
# - Log guardrail violations

# %% [markdown]
# Legacy practice content from practice.ipynb
#
# ## Overview
#
# Guardrails keep agents safe and predictable. You will implement a checklist
# and enforce it in the agent loop.
#
# You will:
#
# 1. Define guardrail config.
# 2. Enforce allowed tools and step caps.
# 3. Return clear errors on violations.
#
# ## Practice Steps
#
# - Define guardrail rules below.
# - Update the runner to enforce them.
# - Simulate a violation and confirm the error.

# %%
# Legacy practice content
from dataclasses import dataclass
from typing import List

@dataclass
class Guardrails:
    allowed_tools: List[str]
    max_steps: int

def check_guardrails(tool_name: str, step: int, rules: Guardrails) -> None:
    if tool_name not in rules.allowed_tools:
        raise ValueError("tool not allowed")
    if step >= rules.max_steps:
        raise ValueError("step cap exceeded")

rules = Guardrails(allowed_tools=["search"], max_steps=3)

# TODO: integrate guardrails into your agent runner

# %% [markdown]
# Legacy practice content from practice.ipynb
#
# ## Self-check
#
# - Do guardrails prevent unsafe tools?
# - Are errors clear and structured?
# - Are step caps enforced?
