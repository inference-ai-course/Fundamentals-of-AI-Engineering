# %% [markdown]
# # Level 2 — Week 7 Practice (Starter Notebook)
#
# Starter templates for: Agent Design Patterns (Planning, Guardrails, and Multi-Step Tasks).
#
# ## References (docs)
# - OpenTelemetry Python: https://opentelemetry.io/docs/languages/python/
# - Python `logging`: https://docs.python.org/3/library/logging.html

# %% [markdown]
# ## Guardrail checklist (starter)
#
# - Allowed tools list
# - Step cap
# - Timeout cap
# - Budget cap
#
# Add these as explicit checks in your agent runner.
