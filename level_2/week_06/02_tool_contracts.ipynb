# %% [markdown]
# # Level 2 - Week 6 - 02 Tool Contracts
#
# **Estimated time:** 60-90 minutes
#
# ## Learning Objectives
#
# - Define tool input and output schemas
# - Validate preconditions
# - Handle failure modes

# %% [markdown]
# ## Overview
#
# Tool contracts make agent behavior safe and testable.
# Validate inputs before running tools.
#
# ## Practice Steps
#
# - Define a tool schema for search.
# - Validate tool outputs.

# %% [markdown]
# ### Sample code
#
# Minimal tool schema and validation.

# %%
tool_schema = {
    'name': 'search',
    'input_schema': {
        'query': 'string',
        'top_k': 'int',
        'filters': 'dict|none',
    },
    'output_schema': {
        'hits': 'list',
    },
}

print(tool_schema)

# %% [markdown]
# ### Student fill-in
#
# Add preconditions and postconditions for search.

# %%
def validate_search_input(query: str, top_k: int) -> None:
    # TODO: enforce min length and bounds
    pass

# %% [markdown]
# ## Self-check
#
# - Do invalid tool inputs fail fast?
# - Are output schemas explicit?
