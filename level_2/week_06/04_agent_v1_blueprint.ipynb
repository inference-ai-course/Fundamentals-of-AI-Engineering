# %% [markdown]
# # Level 2 - Week 6 - 04 Agent v1 Blueprint
#
# **Estimated time:** 60-90 minutes
#
# ## Learning Objectives
#
# - Define a two-tool plan
# - Record steps and outputs
# - Validate citations

# %% [markdown]
# ## Overview
#
# A minimal agent uses search then write_answer.
# Keep the plan short and logged.
#
# ## Practice Steps
#
# - Draft the agent flow.
# - Add a citation validation step.

# %% [markdown]
# ### Sample code
#
# Agent blueprint with search and write_answer.

# %%
AGENT_FLOW = {
    'plan': ['search', 'write_answer'],
    'steps': ['call search', 'call write_answer', 'validate citations', 'return final'],
}

print(AGENT_FLOW)

# %% [markdown]
# ### Student fill-in
#
# Add a validation step to the blueprint.

# %%
# TODO: write the validation step logic

# %% [markdown]
# ## Self-check
#
# - Is the plan short and explicit?
# - Are steps logged for debugging?
