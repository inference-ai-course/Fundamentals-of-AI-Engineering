# %% [markdown]
# # Level 2 - Week 6 - 03 Reliability and Step Logs
#
# **Estimated time:** 60-90 minutes
#
# ## Learning Objectives
#
# - Add bounded retries
# - Use backoff
# - Log step metadata

# %% [markdown]
# ## Overview
#
# Retries improve reliability when bounded and logged.
# Step logs make failures traceable.
#
# ## Practice Steps
#
# - Implement a retry wrapper.
# - Define step log fields.

# %% [markdown]
# ### Sample code
#
# Retry wrapper with backoff.

# %%
import time


def with_retries(fn, max_retries: int = 2, base_delay_s: float = 0.2):
    for attempt in range(max_retries + 1):
        try:
            return fn()
        except Exception:
            if attempt >= max_retries:
                raise
            time.sleep(base_delay_s * (2 ** attempt))

# %% [markdown]
# ### Student fill-in
#
# Define step log fields for each tool call.

# %%
STEP_LOG_FIELDS = [
    'request_id',
    'step_index',
    'tool',
    'input',
    'output',
    'error',
    'latency_ms',
]

# TODO: add jitter to retries
print(STEP_LOG_FIELDS)

# %% [markdown]
# ## Self-check
#
# - Are retries bounded?
# - Do step logs include request_id?
