# %% [markdown]
# # Level 2 - Week 8 - 02 Sessions, Permissions, Audit
#
# **Estimated time:** 60-90 minutes
#
# ## Learning Objectives
#
# - Define session schema
# - Specify permission rules
# - Capture audit logs

# %% [markdown]
# ## Overview
#
# Admin endpoints require permissions and audit trails.
# Start with the simplest workable model.
#
# ## Practice Steps
#
# - Define session fields and roles.
# - Draft an audit log entry.

# %% [markdown]
# ### Sample code
#
# Session schema and audit log entry.

# %%
SESSION_SCHEMA = {
    'session_id': 'string',
    'user_id': 'string',
    'role': 'user|admin',
}

AUDIT_ENTRY = {
    'request_id': 'req-123',
    'actor': 'admin',
    'action': 'ingest',
    'resource': 'data/doc.md',
    'status': 'success',
}

print(SESSION_SCHEMA)
print(AUDIT_ENTRY)

# %% [markdown]
# ### Student fill-in
#
# Add permission checks for admin routes.

# %%
def can_access(role: str, endpoint: str) -> bool:
    # TODO: implement permission rules
    return False

# %% [markdown]
# ## Self-check
#
# - Are admin actions logged?
# - Is default deny enforced for admin endpoints?
