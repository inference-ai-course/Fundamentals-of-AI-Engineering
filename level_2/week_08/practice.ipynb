# %% [markdown]
# # Level 2 — Week 8 Practice (Starter Notebook)
#
# Starter templates for: Productize RAG + Agents (Service + Front-End).
#
# ## References (docs)
# - FastAPI: https://fastapi.tiangolo.com/
# - Twelve-Factor App: https://12factor.net/

# %% [markdown]
# ## Demo checklist (starter)
#
# - One-command run
# - One successful query
# - One failure-case query
# - Show citations
# - Show evaluation evidence
