# %% [markdown]
# # Level 2 - Week 8 - 03 Demo Packaging
#
# **Estimated time:** 60-90 minutes
#
# ## Learning Objectives
#
# - Create a demo checklist
# - Document one-command run
# - Capture expected outputs

# %% [markdown]
# ## Overview
#
# A demo is successful if others can reproduce it.
# Document commands and expected outputs.
#
# ## Practice Steps
#
# - Write a demo checklist.
# - List run command and test request.

# %% [markdown]
# ### Sample code
#
# Checklist template.

# %%
DEMO_CHECKLIST = [
    'run service',
    'call /health',
    'run in-KB query',
    'run out-of-KB query',
]

print(DEMO_CHECKLIST)

# %% [markdown]
# ### Student fill-in
#
# Add commands and expected output notes.

# %%
RUN_COMMAND = 'uvicorn app.main:app --port 8000'
TEST_COMMAND = 'curl -s http://localhost:8000/health'

# TODO: add expected outputs

# %% [markdown]
# ## Self-check
#
# - Can a teammate run without help?
# - Is a failure case included?
