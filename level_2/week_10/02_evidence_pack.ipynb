# %% [markdown]
# # Level 2 - Week 10 - 02 Evidence Pack
#
# **Estimated time:** 60-90 minutes
#
# ## Learning Objectives
#
# - List artifacts to include
# - Describe before and after change
# - Tie evidence to a claim

# %% [markdown]
# ## Overview
#
# Evidence packs are reproducible summaries of evaluation.
# Include metrics and failures.
#
# ## Practice Steps
#
# - List artifacts for the run.
# - Write a before vs after statement.

# %% [markdown]
# ### Sample code
#
# Artifact list template.

# %%
ARTIFACTS = [
    'config.json',
    'metrics.json',
    'failures.json',
    'samples.md',
]

print(ARTIFACTS)

# %% [markdown]
# ### Student fill-in
#
# Add a before vs after comparison note.

# %%
# TODO: describe change -> metric movement -> interpretation

# %% [markdown]
# ## Self-check
#
# - Can someone rerun the artifacts?
# - Is the change clearly documented?
