# %% [markdown]
# # Level 2 — Week 10 Practice (Starter Notebook)
#
# Starter templates for: Capstone Sprint & Defense (Assessable Delivery).
#
# ## References (docs)
# - Twelve-Factor App: https://12factor.net/

# %% [markdown]
# ## Defense prep template
#
# - Architecture diagram
# - Key tradeoffs
# - Evidence (metrics + failure cases)
# - Roadmap
