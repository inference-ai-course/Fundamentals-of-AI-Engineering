# %% [markdown]
# # Level 2 - Week 10 - 03 Defense Checklist
#
# **Estimated time:** 60-90 minutes
#
# ## Learning Objectives
#
# - Summarize architecture
# - Explain tradeoffs
# - Outline next steps

# %% [markdown]
# ## Overview
#
# Defense means you can explain:
#
# - what you built
# - why you chose these components
# - tradeoffs you accepted
# - limitations
# - next roadmap
#
# ## Underlying theory: defend with tradeoffs, not vibes
#
# A strong defense is:
#
# - explicit constraints (time, cost, latency, security)
# - design choices that follow from constraints
# - evaluation evidence showing the consequences
#
# ### Falsifiable claims
#
# Prefer claims you can test against artifacts:
#
# - “Recall@5 improved from 0.50 to 0.65 after increasing overlap”
# - “Out-of-KB questions refuse when top score < τ”
#
# ### Tradeoff framing
#
# Most questions reduce to a tradeoff:
#
# - precision vs recall (retrieval)
# - latency vs reliability (retries)
# - strict validation vs UX (citation substring checks)
#
# ## Practice Steps
#
# - Fill in the checklist items.
# - Write two likely defense questions and short evidence-based answers.

# %% [markdown]
# ### Sample code
#
# Checklist template.

# %%
DEFENSE_CHECKLIST = [
    'architecture diagram',
    'data flow',
    'failure modes and mitigations',
    'cost controls',
    'security posture',
    'next iterations',
]

print(DEFENSE_CHECKLIST)

# %% [markdown]
# ### Student fill-in
#
# Add your tradeoffs and roadmap.

# %%
TRADEOFFS = {
    "precision_vs_recall": "<what you chose and why>",
    "latency_vs_reliability": "<what you chose and why>",
    "strictness_vs_ux": "<what you chose and why>",
}

LIMITATIONS = [
    "<limitation 1>",
    "<limitation 2>",
    "<limitation 3>",
]

ROADMAP_NEXT_2 = [
    "<iteration 1 tied to evidence>",
    "<iteration 2 tied to evidence>",
]

DEFENSE_QA = [
    {
        "q": "Why did you choose your embedding model and vector store?",
        "a": "<evidence-based answer: constraints + what you measured>",
    },
    {
        "q": "What are your top 3 observed failure modes, and how did you mitigate them?",
        "a": "<point to failures.json labels + one concrete change or fallback>",
    },
]

print("tradeoffs:")
for k, v in TRADEOFFS.items():
    print("-", k, ":", v)

print("limitations:")
for s in LIMITATIONS:
    print("-", s)

print("roadmap_next_2:")
for s in ROADMAP_NEXT_2:
    print("-", s)

print("defense_qa:")
for item in DEFENSE_QA:
    print("Q:", item["q"])
    print("A:", item["a"])

# %% [markdown]
# ## Self-check
#
# - Are tradeoffs explicit?
# - Is roadmap realistic?
