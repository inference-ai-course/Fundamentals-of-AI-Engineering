# %% [markdown]
# # Level 2 - Week 10 - 03 Defense Checklist
#
# **Estimated time:** 60-90 minutes
#
# ## Learning Objectives
#
# - Summarize architecture
# - Explain tradeoffs
# - Outline next steps

# %% [markdown]
# ## Overview
#
# Defense means explaining tradeoffs and evidence, not just results.
# Use the checklist to prepare.
#
# ## Practice Steps
#
# - Fill in architecture, tradeoffs, limitations, and roadmap.
# - Write two likely questions and answers.

# %% [markdown]
# ### Sample code
#
# Checklist template.

# %%
DEFENSE_CHECKLIST = [
    'architecture diagram',
    'data flow',
    'failure modes and mitigations',
    'cost controls',
    'security posture',
    'next iterations',
]

print(DEFENSE_CHECKLIST)

# %% [markdown]
# ### Student fill-in
#
# Add your tradeoffs and roadmap.

# %%
# TODO: write tradeoffs and next steps

# %% [markdown]
# ## Self-check
#
# - Are tradeoffs explicit?
# - Is roadmap realistic?
