# %% [markdown]
# # Level 2 - Week 10 - 01 Demo Script
#
# **Estimated time:** 60-90 minutes
#
# ## Learning Objectives
#
# - Define demo steps
# - Include a failure case
# - Call out evidence

# %% [markdown]
# ## Overview
#
# A demo should show success, failure, and evidence.
# Keep the script short and repeatable.
#
# ## Practice Steps
#
# - Write the demo steps.
# - Add a failure case and evidence points.

# %% [markdown]
# ### Sample code
#
# Demo steps template.

# %%
DEMO_STEPS = [
    'state problem and constraints',
    'show architecture diagram',
    'run in-KB query with citations',
    'run out-of-KB query with refuse',
    'show metrics and failures',
]

print(DEMO_STEPS)

# %% [markdown]
# ### Student fill-in
#
# Add timing and specific queries.

# %%
# TODO: add queries and timing per step

# %% [markdown]
# ## Self-check
#
# - Is a failure case included?
# - Are evidence artifacts referenced?

# %% [markdown]
# Legacy practice content from practice.ipynb
#
# # Level 2 — Week 10 Practice: Capstone Sprint
#
# **Estimated time:** 60–90 minutes
#
# ## Learning Objectives
#
# - Summarize architecture and tradeoffs
# - Present evidence and failure cases
# - Prepare a defense narrative
# - Define next-step roadmap

# %% [markdown]
# Legacy practice content from practice.ipynb
#
# ## Overview
#
# The capstone is a short sprint to package your work for assessment. You will
# summarize architecture, provide evidence, and prepare a defense narrative.
#
# You will:
#
# 1. Draft an architecture summary.
# 2. List tradeoffs and limitations.
# 3. Provide evidence (metrics + failure cases).
# 4. Define a roadmap.
#
# ## Practice Steps
#
# - Fill in the defense template below.
# - Add links to evidence artifacts.
# - Prepare your final demo checklist.

# %%
# Legacy practice content
DEFENSE_TEMPLATE = """
Architecture summary:
- Components:
- Data flow:

Tradeoffs:
- 

Evidence:
- Metrics:
- Failure cases:

Roadmap:
- 
"""

print(DEFENSE_TEMPLATE)

# %% [markdown]
# Legacy practice content from practice.ipynb
#
# ## Self-check
#
# - Is the story concise and evidence-based?
# - Are tradeoffs explicit?
# - Is the roadmap realistic?
