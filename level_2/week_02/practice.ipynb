# %% [markdown]
# # Level 2 — Week 2 Practice (Starter Notebook)
#
# Starter templates for: RAG + Vector DB Foundations (Ingestion to Index).
#
# ## References (docs)
# - Chroma docs: https://docs.trychroma.com/
# - Milvus docs (GitHub): https://github.com/milvus-io/milvus-docs
# - SentenceTransformers: https://www.sbert.net/
# - RAG overview (Pinecone): https://www.pinecone.io/learn/retrieval-augmented-generation/

# %% [markdown]
# ## Ingestion pipeline shape
#
# This cell is a template: parse -> chunk -> embed -> upsert.

# %%
from dataclasses import dataclass
from typing import List, Dict

@dataclass
class Chunk:
    doc_id: str
    chunk_id: str
    text: str
    metadata: Dict

def chunk_text(text: str, doc_id: str) -> List[Chunk]:
    # TODO: implement chunking strategy
    return [Chunk(doc_id=doc_id, chunk_id="0", text=text, metadata={"doc_id": doc_id})]
