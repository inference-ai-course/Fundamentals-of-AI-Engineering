# %% [markdown]
# # Level 2 — Week 9 Practice (Starter Notebook)
#
# Starter templates for: Hardening & Operations (Reliability, Security, and Scale).
#
# ## References (docs)
# - OpenTelemetry Python: https://opentelemetry.io/docs/languages/python/
# - HTTP 429 (MDN): https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/429
# - structlog: https://www.structlog.org/en/stable/

# %% [markdown]
# ## Observability quickstart (starter)
#
# Instrument key spans: ingestion, retrieval, generation, tool calls.
