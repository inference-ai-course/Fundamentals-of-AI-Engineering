# %% [markdown]
# # Level 2 - Week 9 - 02 Rate Limiting and Retry Policies
#
# **Estimated time:** 60-90 minutes
#
# ## Learning Objectives
#
# - Define rate limit policy
# - Set retry bounds
# - Clarify retryable errors

# %% [markdown]
# ## Overview
#
# Retries amplify load, so they need bounds and backoff.
# Rate limits protect expensive endpoints.
#
# ## Practice Steps
#
# - Write a policy dict.
# - Decide which errors are retryable.

# %% [markdown]
# ### Sample code
#
# Policy template and retry decision.

# %%
POLICY = {
    'max_attempts': 3,
    'base_delay_ms': 200,
    'max_delay_ms': 2000,
    'rate_limit_rpm': 60,
}

RETRYABLE = {'timeout', '429', '5xx'}

print(POLICY)
print(RETRYABLE)

# %% [markdown]
# ### Student fill-in
#
# Add a should_retry helper.

# %%
def should_retry(error_type: str) -> bool:
    # TODO: implement retry logic
    return False

# %% [markdown]
# ## Self-check
#
# - Are retries bounded?
# - Are rate limits documented?
