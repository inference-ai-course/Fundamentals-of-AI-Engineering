# %% [markdown]
# # Level 2 - Week 9 - 03 Ops Checklist
#
# **Estimated time:** 60-90 minutes
#
# ## Learning Objectives
#
# - List what to monitor
# - Define debug steps
# - Document cost controls

# %% [markdown]
# ## Overview
#
# Ops checklists are runbooks for failures.
# They reduce demo chaos.
#
# ## Practice Steps
#
# - Draft a checklist with monitoring and debug steps.
# - Add cost control items.

# %% [markdown]
# ### Sample code
#
# Ops checklist template.

# %%
OPS_CHECKLIST = [
    'monitor latency p95',
    'monitor error rate',
    'monitor refusal rate',
    'log request_id on failures',
]

print(OPS_CHECKLIST)

# %% [markdown]
# ### Student fill-in
#
# Add a debug sequence for retrieval misses.

# %%
# TODO: add debug steps for retrieval miss

# %% [markdown]
# ## Self-check
#
# - Is there a clear debug procedure?
# - Are cost controls listed?
