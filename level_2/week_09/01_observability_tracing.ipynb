# %% [markdown]
# # Level 2 - Week 9 - 01 Observability and Tracing
#
# **Estimated time:** 60-90 minutes
#
# ## Learning Objectives
#
# - Define log fields
# - Identify spans
# - Track latency and errors

# %% [markdown]
# ## Overview
#
# Logs explain what happened; traces show where time went.
# Start with a minimal observability package.
#
# ## Practice Steps
#
# - List required log fields.
# - Define core spans.

# %% [markdown]
# ### Sample code
#
# Minimal fields and spans.

# %%
LOG_FIELDS = ['request_id', 'path', 'status_code', 'latency_ms', 'component']
SPANS = ['ingestion', 'retrieval', 'generation', 'validation']

print(LOG_FIELDS)
print(SPANS)

# %% [markdown]
# ### Student fill-in
#
# Add RAG-specific fields (top_k, context length).

# %%
# TODO: extend LOG_FIELDS with RAG fields

# %% [markdown]
# ## Self-check
#
# - Do logs include request_id?
# - Are spans defined for critical path?

# %% [markdown]
# Legacy practice content from practice.ipynb
#
# # Level 2 — Week 9 Practice: Reliability + Operations
#
# **Estimated time:** 60–90 minutes
#
# ## Learning Objectives
#
# - Define basic reliability targets (timeouts, retries)
# - Add observability spans and structured logs
# - Identify security considerations
# - Create a small ops checklist

# %% [markdown]
# Legacy practice content from practice.ipynb
#
# ## Overview
#
# This week focuses on operational hardening. You will define reliability targets
# and outline observability instrumentation.
#
# You will:
#
# 1. Define timeouts + retries for key operations.
# 2. Identify critical spans for tracing.
# 3. Capture a short ops checklist.
#
# ## Practice Steps
#
# - Fill in the reliability targets.
# - Add spans to the list below.
# - Record security considerations.

# %% [markdown]
# Legacy practice content from practice.ipynb
#
# ### Task 9.1: Reliability targets
#
# Fill in target values for timeout and retry counts.

# %%
# Legacy practice content
RELIABILITY_TARGETS = {
    "ingestion_timeout_s": 10,
    "retrieval_timeout_s": 2,
    "generation_timeout_s": 15,
    "max_retries": 2,
}

# TODO: adjust targets based on your system
print(RELIABILITY_TARGETS)

# %% [markdown]
# Legacy practice content from practice.ipynb
#
# ### Task 9.2: Observability spans
#
# List the spans you will instrument.

# %%
# Legacy practice content
SPAN_CHECKLIST = """
- ingestion.parse
- ingestion.chunk
- retrieval.search
- generation.answer
- tool.call
"""

print(SPAN_CHECKLIST)

# %% [markdown]
# Legacy practice content from practice.ipynb
#
# ## Self-check
#
# - Are targets realistic?
# - Are spans covering critical paths?
# - Are security risks noted?
