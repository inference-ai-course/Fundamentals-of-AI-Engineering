# %% [markdown]
# # Level 2 — Week 1 Practice (Starter Notebook)
#
# Starter templates for: From Requirements to Architecture (AI Application System View).
#
# ## References (docs)
# - FastAPI: https://fastapi.tiangolo.com/
# - Pydantic: https://docs.pydantic.dev/latest/
# - Uvicorn: https://www.uvicorn.org/
# - Python `logging`: https://docs.python.org/3/library/logging.html
# - HTTP status codes (MDN): https://developer.mozilla.org/en-US/docs/Web/HTTP/Status
# - python-dotenv (GitHub): https://github.com/theskumar/python-dotenv

# %% [markdown]
# ## FastAPI skeleton (minimal)
#
# This is a minimal service skeleton you can copy into `app/main.py`.

# %%
from fastapi import FastAPI
from pydantic import BaseModel

app = FastAPI(title="Level2 Service")

class HealthResponse(BaseModel):
    status: str

@app.get("/health", response_model=HealthResponse)
def health():
    return HealthResponse(status="ok")
