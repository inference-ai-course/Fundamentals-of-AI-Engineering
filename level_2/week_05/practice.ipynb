# %% [markdown]
# # Level 2 — Week 5 Practice (Starter Notebook)
#
# Starter templates for: RAG Quality Iteration + Minimal Evaluation (Compressed).
#
# ## References (docs)
# - Python `logging`: https://docs.python.org/3/library/logging.html
# - RAG overview (Pinecone): https://www.pinecone.io/learn/retrieval-augmented-generation/

# %% [markdown]
# ## Minimal evaluation script shape
#
# Start with 10–20 items and print failures.

# %%
from typing import List, Dict

def evaluate(items: List[Dict]):
    # TODO: implement your eval loop
    # Example metrics: citation_coverage, answer_nonempty, refusal_rate
    return {"n": len(items)}
